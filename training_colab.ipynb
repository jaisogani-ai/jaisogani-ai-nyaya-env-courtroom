# %% [markdown]
# # 🏛️ Nyaya-Env — Unsloth GRPO Training
#
# **Meta PyTorch OpenEnv Hackathon India 2026**
#
# This notebook executes the AI Safety via Debate reinforcement learning pipeline. We use **GRPO (Group Relative Policy Optimization)** via TRL and Unsloth to train our Legal Agents (Qwen2.5-1.5B) to argue Indian Bail Law (BNSS 2023).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "trl<0.9.0" peft accelerate bitsandbytes
# !pip install openenv-core fastapi pydantic
# !pip install vllm

# %% [markdown]
# ## 2. Clone Repository & Setup Environment

# %%
# !git clone https://github.com/jaisogani-ai/nyaya-env.git
# %cd nyaya-env

import sys
sys.path.insert(0, '.')

print("✅ Setup Complete")

# %% [markdown]
# ## 3. Launch GRPO GPU Training
#
# This executes `train_grpo_gpu` from `train_grpo.py`. It uses:
# - Unsloth 4-bit quantization
# - `dr_grpo` loss (DeepSeek-R1 style)
# - 8 composite reward functions (including Snorkel BNSS labelers)

# %%
from train_grpo import train_grpo_gpu

# Start training pipeline. Fits on a free Colab T4 GPU.
# Note: Cold-start SFT weights are recommended before running this block.
train_grpo_gpu(
    model_name="Qwen/Qwen2.5-1.5B-Instruct",
    num_episodes=500,
    seed=3407
)
